# %% [markdown]
# <a href="https://colab.research.google.com/github/Athish-Pranav/skin-cancer-classification/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import tensorflow_hub as hub
import os
from keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
train_dir='/content/drive/MyDrive/train'
Labels = ['Benign', 'Malignant']
print ("class : ")
for i in range(len(Labels)):
    print (i, end = " ")
    print (Labels[i])
# Out:
# class :
# 0 Benign
# 1 Malignant

# %%
module_selection = ("mobilenet_v2", 224, 1280)
handle_base, pixels, FV_SIZE = module_selection
MODULE_HANDLE ="https://tfhub.dev/google/tf2-preview/{}/feature_vector/2".format(handle_base)
IMAGE_SIZE = (pixels, pixels)
BATCH_SIZE = 16

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
      rescale = 1./255,
      rotation_range=40,
      horizontal_flip=True,
      width_shift_range=0.2,
      height_shift_range=0.2,
      shear_range=0.2,
      zoom_range=0.2,
      fill_mode='nearest',
      validation_split=0.3)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    subset="training",
    shuffle=True,
    seed=42,
    color_mode="rgb",
    class_mode="categorical",
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    shuffle=False,
    seed=42,
    color_mode="rgb",
    class_mode="categorical",
    subset="validation",
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE)
# Out:
# Found 1846 images belonging to 2 classes.
# Found 791 images belonging to 2 classes.

# %%
feature_extractor = hub.KerasLayer(MODULE_HANDLE,input_shape=IMAGE_SIZE+(3,), output_shape=[FV_SIZE])
do_fine_tuning = False
if do_fine_tuning:
  feature_extractor.trainable = True
  for layer in base_model.layers[-30:]:
    layer.trainable =True

else:
  feature_extractor.trainable = False

print("Building model with", MODULE_HANDLE)
model = tf.keras.Sequential([
    feature_extractor,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(train_generator.num_classes, activation='softmax',
                           kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])

model.summary()
# Out:
# Building model with https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/2
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense (Dense)               (None, 512)               655872
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 2,914,882
# Trainable params: 656,898
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
LEARNING_RATE = 0.001
model.compile(
   optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
   loss='categorical_crossentropy',
   metrics=['accuracy'])

# %%
EPOCHS=200
history = model.fit(
        train_generator,
        steps_per_epoch=train_generator.samples//train_generator.batch_size,
        epochs=EPOCHS,
        validation_data=validation_generator,
        validation_steps=validation_generator.samples//validation_generator.batch_size)
# Out:
# Epoch 1/200
# 115/115 [==============================] - 945s 8s/step - loss: 0.4952 - accuracy: 0.7858 - val_loss: 0.4855 - val_accuracy: 0.7793
# Epoch 2/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.3453 - accuracy: 0.8497 - val_loss: 0.7461 - val_accuracy: 0.6760
# Epoch 3/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.3278 - accuracy: 0.8634 - val_loss: 0.4396 - val_accuracy: 0.8189
# Epoch 4/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.3051 - accuracy: 0.8607 - val_loss: 0.5483 - val_accuracy: 0.7500
# Epoch 5/200
# 115/115 [==============================] - 39s 336ms/step - loss: 0.3064 - accuracy: 0.8639 - val_loss: 0.4839 - val_accuracy: 0.7538
# Epoch 6/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.2756 - accuracy: 0.8787 - val_loss: 0.4503 - val_accuracy: 0.7934
# Epoch 7/200
# 115/115 [==============================] - 38s 333ms/step - loss: 0.2761 - accuracy: 0.8705 - val_loss: 0.4375 - val_accuracy: 0.8074
# Epoch 8/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.2632 - accuracy: 0.8874 - val_loss: 0.4732 - val_accuracy: 0.7742
# Epoch 9/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.2528 - accuracy: 0.8803 - val_loss: 0.5815 - val_accuracy: 0.7474
# Epoch 10/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.2429 - accuracy: 0.8945 - val_loss: 0.5174 - val_accuracy: 0.7577
# Epoch 11/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.2440 - accuracy: 0.8989 - val_loss: 0.5292 - val_accuracy: 0.7742
# Epoch 12/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.2407 - accuracy: 0.8951 - val_loss: 0.6291 - val_accuracy: 0.7296
# Epoch 13/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.2348 - accuracy: 0.9005 - val_loss: 0.5919 - val_accuracy: 0.7513
# Epoch 14/200
# 115/115 [==============================] - 48s 417ms/step - loss: 0.2282 - accuracy: 0.8956 - val_loss: 0.5301 - val_accuracy: 0.7806
# Epoch 15/200
# 115/115 [==============================] - 38s 328ms/step - loss: 0.2196 - accuracy: 0.9126 - val_loss: 0.4530 - val_accuracy: 0.8151
# Epoch 16/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.2295 - accuracy: 0.8989 - val_loss: 0.4821 - val_accuracy: 0.7934
# Epoch 17/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.2025 - accuracy: 0.9087 - val_loss: 0.4925 - val_accuracy: 0.7934
# Epoch 18/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.2068 - accuracy: 0.9153 - val_loss: 0.5470 - val_accuracy: 0.7653
# Epoch 19/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.2000 - accuracy: 0.9115 - val_loss: 0.5184 - val_accuracy: 0.7908
# Epoch 20/200
# 115/115 [==============================] - 38s 334ms/step - loss: 0.2072 - accuracy: 0.9066 - val_loss: 0.5637 - val_accuracy: 0.7602
# Epoch 21/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1963 - accuracy: 0.9213 - val_loss: 0.5790 - val_accuracy: 0.7577
# Epoch 22/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.1877 - accuracy: 0.9235 - val_loss: 0.5238 - val_accuracy: 0.7730
# Epoch 23/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.1866 - accuracy: 0.9213 - val_loss: 0.4924 - val_accuracy: 0.8048
# Epoch 24/200
# 115/115 [==============================] - 47s 407ms/step - loss: 0.1841 - accuracy: 0.9180 - val_loss: 0.5665 - val_accuracy: 0.7819
# Epoch 25/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1855 - accuracy: 0.9224 - val_loss: 0.4968 - val_accuracy: 0.7946
# Epoch 26/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.1700 - accuracy: 0.9251 - val_loss: 0.5675 - val_accuracy: 0.7895
# Epoch 27/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.1897 - accuracy: 0.9175 - val_loss: 0.5106 - val_accuracy: 0.8202
# Epoch 28/200
# 115/115 [==============================] - 38s 333ms/step - loss: 0.1891 - accuracy: 0.9240 - val_loss: 0.5449 - val_accuracy: 0.7806
# Epoch 29/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.1850 - accuracy: 0.9290 - val_loss: 0.5866 - val_accuracy: 0.7666
# Epoch 30/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.1818 - accuracy: 0.9246 - val_loss: 0.5010 - val_accuracy: 0.8329
# Epoch 31/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.1641 - accuracy: 0.9290 - val_loss: 0.5017 - val_accuracy: 0.8010
# Epoch 32/200
# 115/115 [==============================] - 37s 323ms/step - loss: 0.1509 - accuracy: 0.9333 - val_loss: 0.6148 - val_accuracy: 0.7755
# Epoch 33/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.1538 - accuracy: 0.9295 - val_loss: 0.5042 - val_accuracy: 0.8112
# Epoch 34/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.1508 - accuracy: 0.9372 - val_loss: 0.5942 - val_accuracy: 0.7921
# Epoch 35/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.1600 - accuracy: 0.9301 - val_loss: 0.5732 - val_accuracy: 0.7921
# Epoch 36/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.1511 - accuracy: 0.9306 - val_loss: 0.6489 - val_accuracy: 0.7500
# Epoch 37/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.1652 - accuracy: 0.9317 - val_loss: 0.7480 - val_accuracy: 0.7462
# Epoch 38/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.1445 - accuracy: 0.9377 - val_loss: 0.6263 - val_accuracy: 0.7844
# Epoch 39/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.1486 - accuracy: 0.9377 - val_loss: 0.7544 - val_accuracy: 0.7577
# Epoch 40/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.1401 - accuracy: 0.9437 - val_loss: 0.5990 - val_accuracy: 0.7946
# Epoch 41/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.1511 - accuracy: 0.9322 - val_loss: 0.6603 - val_accuracy: 0.7768
# Epoch 42/200
# 115/115 [==============================] - 47s 406ms/step - loss: 0.1272 - accuracy: 0.9486 - val_loss: 0.5902 - val_accuracy: 0.7755
# Epoch 43/200
# 115/115 [==============================] - 37s 322ms/step - loss: 0.1299 - accuracy: 0.9470 - val_loss: 0.5564 - val_accuracy: 0.7959
# Epoch 44/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.1335 - accuracy: 0.9437 - val_loss: 0.5817 - val_accuracy: 0.8367
# Epoch 45/200
# 115/115 [==============================] - 39s 337ms/step - loss: 0.1396 - accuracy: 0.9388 - val_loss: 0.7532 - val_accuracy: 0.7589
# Epoch 46/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1347 - accuracy: 0.9448 - val_loss: 0.6996 - val_accuracy: 0.7602
# Epoch 47/200
# 115/115 [==============================] - 38s 334ms/step - loss: 0.1351 - accuracy: 0.9508 - val_loss: 0.5797 - val_accuracy: 0.7946
# Epoch 48/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.1223 - accuracy: 0.9432 - val_loss: 0.5645 - val_accuracy: 0.8099
# Epoch 49/200
# 115/115 [==============================] - 49s 424ms/step - loss: 0.1372 - accuracy: 0.9464 - val_loss: 0.6680 - val_accuracy: 0.7946
# Epoch 50/200
# 115/115 [==============================] - 39s 341ms/step - loss: 0.1328 - accuracy: 0.9432 - val_loss: 0.6096 - val_accuracy: 0.8061
# Epoch 51/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.1347 - accuracy: 0.9486 - val_loss: 0.6213 - val_accuracy: 0.7730
# Epoch 52/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.1440 - accuracy: 0.9404 - val_loss: 0.4887 - val_accuracy: 0.8304
# Epoch 53/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.1303 - accuracy: 0.9481 - val_loss: 0.6307 - val_accuracy: 0.7730
# Epoch 54/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.1240 - accuracy: 0.9459 - val_loss: 0.6532 - val_accuracy: 0.7793
# Epoch 55/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.1199 - accuracy: 0.9530 - val_loss: 0.5966 - val_accuracy: 0.8112
# Epoch 56/200
# 115/115 [==============================] - 37s 325ms/step - loss: 0.1109 - accuracy: 0.9536 - val_loss: 0.6486 - val_accuracy: 0.7908
# Epoch 57/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1273 - accuracy: 0.9475 - val_loss: 0.6130 - val_accuracy: 0.8265
# Epoch 58/200
# 115/115 [==============================] - 37s 325ms/step - loss: 0.0957 - accuracy: 0.9612 - val_loss: 0.7181 - val_accuracy: 0.7704
# Epoch 59/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1096 - accuracy: 0.9585 - val_loss: 0.6721 - val_accuracy: 0.7755
# Epoch 60/200
# 115/115 [==============================] - 48s 416ms/step - loss: 0.1106 - accuracy: 0.9574 - val_loss: 0.6908 - val_accuracy: 0.7742
# Epoch 61/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1073 - accuracy: 0.9541 - val_loss: 0.5481 - val_accuracy: 0.8189
# Epoch 62/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.1038 - accuracy: 0.9574 - val_loss: 0.5631 - val_accuracy: 0.8189
# Epoch 63/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.1057 - accuracy: 0.9623 - val_loss: 0.6307 - val_accuracy: 0.8048
# Epoch 64/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.1013 - accuracy: 0.9596 - val_loss: 0.7278 - val_accuracy: 0.7972
# Epoch 65/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.1035 - accuracy: 0.9541 - val_loss: 0.6662 - val_accuracy: 0.7895
# Epoch 66/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0969 - accuracy: 0.9612 - val_loss: 0.6777 - val_accuracy: 0.7832
# Epoch 67/200
# 115/115 [==============================] - 47s 407ms/step - loss: 0.1058 - accuracy: 0.9596 - val_loss: 0.7765 - val_accuracy: 0.7921
# Epoch 68/200
# 115/115 [==============================] - 47s 407ms/step - loss: 0.1148 - accuracy: 0.9546 - val_loss: 0.6115 - val_accuracy: 0.8010
# Epoch 69/200
# 115/115 [==============================] - 38s 328ms/step - loss: 0.1103 - accuracy: 0.9568 - val_loss: 0.6431 - val_accuracy: 0.8036
# Epoch 70/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0891 - accuracy: 0.9645 - val_loss: 0.6424 - val_accuracy: 0.7997
# Epoch 71/200
# 115/115 [==============================] - 38s 334ms/step - loss: 0.0871 - accuracy: 0.9639 - val_loss: 0.8477 - val_accuracy: 0.7972
# Epoch 72/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0930 - accuracy: 0.9623 - val_loss: 0.6621 - val_accuracy: 0.8087
# Epoch 73/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0855 - accuracy: 0.9617 - val_loss: 0.7861 - val_accuracy: 0.7972
# Epoch 74/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0967 - accuracy: 0.9628 - val_loss: 0.8633 - val_accuracy: 0.7462
# Epoch 75/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0998 - accuracy: 0.9585 - val_loss: 0.6419 - val_accuracy: 0.8265
# Epoch 76/200
# 115/115 [==============================] - 38s 328ms/step - loss: 0.1008 - accuracy: 0.9639 - val_loss: 0.8066 - val_accuracy: 0.7666
# Epoch 77/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.1031 - accuracy: 0.9590 - val_loss: 0.7432 - val_accuracy: 0.7730
# Epoch 78/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.1119 - accuracy: 0.9563 - val_loss: 0.6595 - val_accuracy: 0.8023
# Epoch 79/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.1010 - accuracy: 0.9590 - val_loss: 0.6654 - val_accuracy: 0.7755
# Epoch 80/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.1049 - accuracy: 0.9596 - val_loss: 0.7200 - val_accuracy: 0.7742
# Epoch 81/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.0727 - accuracy: 0.9727 - val_loss: 0.6736 - val_accuracy: 0.8176
# Epoch 82/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0806 - accuracy: 0.9683 - val_loss: 0.6945 - val_accuracy: 0.8189
# Epoch 83/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0879 - accuracy: 0.9672 - val_loss: 0.6783 - val_accuracy: 0.8304
# Epoch 84/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.0908 - accuracy: 0.9650 - val_loss: 0.6934 - val_accuracy: 0.7742
# Epoch 85/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0844 - accuracy: 0.9650 - val_loss: 0.7016 - val_accuracy: 0.7946
# Epoch 86/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0808 - accuracy: 0.9694 - val_loss: 0.8003 - val_accuracy: 0.7653
# Epoch 87/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0869 - accuracy: 0.9661 - val_loss: 1.0452 - val_accuracy: 0.7462
# Epoch 88/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0974 - accuracy: 0.9634 - val_loss: 0.7418 - val_accuracy: 0.8151
# Epoch 89/200
# 115/115 [==============================] - 38s 335ms/step - loss: 0.0773 - accuracy: 0.9732 - val_loss: 0.7951 - val_accuracy: 0.8036
# Epoch 90/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0703 - accuracy: 0.9721 - val_loss: 0.7926 - val_accuracy: 0.7844
# Epoch 91/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0772 - accuracy: 0.9650 - val_loss: 0.6927 - val_accuracy: 0.7883
# Epoch 92/200
# 115/115 [==============================] - 37s 324ms/step - loss: 0.0650 - accuracy: 0.9749 - val_loss: 0.7000 - val_accuracy: 0.8036
# Epoch 93/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0896 - accuracy: 0.9667 - val_loss: 0.7708 - val_accuracy: 0.8163
# Epoch 94/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0992 - accuracy: 0.9661 - val_loss: 0.6934 - val_accuracy: 0.8125
# Epoch 95/200
# 115/115 [==============================] - 38s 335ms/step - loss: 0.0756 - accuracy: 0.9699 - val_loss: 1.0810 - val_accuracy: 0.7398
# Epoch 96/200
# 115/115 [==============================] - 38s 334ms/step - loss: 0.0704 - accuracy: 0.9738 - val_loss: 0.9260 - val_accuracy: 0.7577
# Epoch 97/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0854 - accuracy: 0.9694 - val_loss: 0.9038 - val_accuracy: 0.7755
# Epoch 98/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0939 - accuracy: 0.9612 - val_loss: 0.6969 - val_accuracy: 0.8112
# Epoch 99/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0762 - accuracy: 0.9661 - val_loss: 0.7587 - val_accuracy: 0.7997
# Epoch 100/200
# 115/115 [==============================] - 38s 335ms/step - loss: 0.0971 - accuracy: 0.9628 - val_loss: 0.7895 - val_accuracy: 0.8061
# Epoch 101/200
# 115/115 [==============================] - 48s 414ms/step - loss: 0.0636 - accuracy: 0.9765 - val_loss: 0.7858 - val_accuracy: 0.7946
# Epoch 102/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0704 - accuracy: 0.9710 - val_loss: 0.8880 - val_accuracy: 0.7819
# Epoch 103/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0733 - accuracy: 0.9732 - val_loss: 1.0269 - val_accuracy: 0.7717
# Epoch 104/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0852 - accuracy: 0.9683 - val_loss: 0.8002 - val_accuracy: 0.7895
# Epoch 105/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0683 - accuracy: 0.9738 - val_loss: 0.8993 - val_accuracy: 0.7742
# Epoch 106/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0934 - accuracy: 0.9656 - val_loss: 0.7612 - val_accuracy: 0.7997
# Epoch 107/200
# 115/115 [==============================] - 37s 326ms/step - loss: 0.0819 - accuracy: 0.9683 - val_loss: 0.8560 - val_accuracy: 0.7793
# Epoch 108/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0810 - accuracy: 0.9661 - val_loss: 0.8061 - val_accuracy: 0.7768
# Epoch 109/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0842 - accuracy: 0.9699 - val_loss: 0.7735 - val_accuracy: 0.8176
# Epoch 110/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0841 - accuracy: 0.9689 - val_loss: 0.7625 - val_accuracy: 0.8099
# Epoch 111/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0740 - accuracy: 0.9699 - val_loss: 0.7948 - val_accuracy: 0.8087
# Epoch 112/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0745 - accuracy: 0.9699 - val_loss: 1.0173 - val_accuracy: 0.7615
# Epoch 113/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0753 - accuracy: 0.9716 - val_loss: 0.6680 - val_accuracy: 0.8253
# Epoch 114/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0670 - accuracy: 0.9765 - val_loss: 0.8012 - val_accuracy: 0.7819
# Epoch 115/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0675 - accuracy: 0.9743 - val_loss: 0.9923 - val_accuracy: 0.7704
# Epoch 116/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0746 - accuracy: 0.9716 - val_loss: 0.8598 - val_accuracy: 0.7844
# Epoch 117/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0700 - accuracy: 0.9732 - val_loss: 0.8056 - val_accuracy: 0.7972
# Epoch 118/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0719 - accuracy: 0.9699 - val_loss: 1.0589 - val_accuracy: 0.7640
# Epoch 119/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0655 - accuracy: 0.9754 - val_loss: 0.9514 - val_accuracy: 0.7844
# Epoch 120/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.1004 - accuracy: 0.9656 - val_loss: 0.7373 - val_accuracy: 0.7934
# Epoch 121/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0701 - accuracy: 0.9694 - val_loss: 0.9976 - val_accuracy: 0.7564
# Epoch 122/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0726 - accuracy: 0.9732 - val_loss: 0.8623 - val_accuracy: 0.7679
# Epoch 123/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.0619 - accuracy: 0.9776 - val_loss: 0.8035 - val_accuracy: 0.7857
# Epoch 124/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0828 - accuracy: 0.9694 - val_loss: 0.8516 - val_accuracy: 0.7819
# Epoch 125/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0696 - accuracy: 0.9749 - val_loss: 0.7844 - val_accuracy: 0.7755
# Epoch 126/200
# 115/115 [==============================] - 47s 413ms/step - loss: 0.0824 - accuracy: 0.9727 - val_loss: 0.7234 - val_accuracy: 0.8023
# Epoch 127/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0561 - accuracy: 0.9792 - val_loss: 0.7552 - val_accuracy: 0.8176
# Epoch 128/200
# 115/115 [==============================] - 47s 407ms/step - loss: 0.0872 - accuracy: 0.9689 - val_loss: 0.9107 - val_accuracy: 0.7679
# Epoch 129/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0667 - accuracy: 0.9743 - val_loss: 0.7492 - val_accuracy: 0.8036
# Epoch 130/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0705 - accuracy: 0.9738 - val_loss: 0.9265 - val_accuracy: 0.7883
# Epoch 131/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0698 - accuracy: 0.9727 - val_loss: 0.9384 - val_accuracy: 0.7717
# Epoch 132/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0587 - accuracy: 0.9743 - val_loss: 0.8386 - val_accuracy: 0.7908
# Epoch 133/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.0717 - accuracy: 0.9716 - val_loss: 0.9143 - val_accuracy: 0.7717
# Epoch 134/200
# 115/115 [==============================] - 48s 416ms/step - loss: 0.0676 - accuracy: 0.9765 - val_loss: 0.9395 - val_accuracy: 0.7832
# Epoch 135/200
# 115/115 [==============================] - 47s 413ms/step - loss: 0.0652 - accuracy: 0.9749 - val_loss: 0.8910 - val_accuracy: 0.7908
# Epoch 136/200
# 115/115 [==============================] - 47s 414ms/step - loss: 0.0809 - accuracy: 0.9716 - val_loss: 0.9030 - val_accuracy: 0.7946
# Epoch 137/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0715 - accuracy: 0.9749 - val_loss: 0.8035 - val_accuracy: 0.7959
# Epoch 138/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0711 - accuracy: 0.9699 - val_loss: 0.9366 - val_accuracy: 0.7832
# Epoch 139/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0632 - accuracy: 0.9749 - val_loss: 0.8428 - val_accuracy: 0.7946
# Epoch 140/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0579 - accuracy: 0.9803 - val_loss: 0.8926 - val_accuracy: 0.8227
# Epoch 141/200
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0553 - accuracy: 0.9749 - val_loss: 0.8682 - val_accuracy: 0.7997
# Epoch 142/200
# 115/115 [==============================] - 38s 333ms/step - loss: 0.0712 - accuracy: 0.9716 - val_loss: 0.8971 - val_accuracy: 0.7870
# Epoch 143/200
# 115/115 [==============================] - 38s 327ms/step - loss: 0.0644 - accuracy: 0.9765 - val_loss: 0.7379 - val_accuracy: 0.8087
# Epoch 144/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0536 - accuracy: 0.9825 - val_loss: 0.9460 - val_accuracy: 0.7819
# Epoch 145/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0706 - accuracy: 0.9743 - val_loss: 0.9410 - val_accuracy: 0.7666
# Epoch 146/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0720 - accuracy: 0.9721 - val_loss: 0.8097 - val_accuracy: 0.8061
# Epoch 147/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0634 - accuracy: 0.9781 - val_loss: 1.0587 - val_accuracy: 0.7857
# Epoch 148/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0635 - accuracy: 0.9749 - val_loss: 0.8760 - val_accuracy: 0.7997
# Epoch 149/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0686 - accuracy: 0.9732 - val_loss: 0.7016 - val_accuracy: 0.8036
# Epoch 150/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0561 - accuracy: 0.9781 - val_loss: 1.0520 - val_accuracy: 0.7793
# Epoch 151/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0508 - accuracy: 0.9820 - val_loss: 0.9987 - val_accuracy: 0.7921
# Epoch 152/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0648 - accuracy: 0.9781 - val_loss: 0.8130 - val_accuracy: 0.7997
# Epoch 153/200
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0720 - accuracy: 0.9705 - val_loss: 1.1076 - val_accuracy: 0.7653
# Epoch 154/200
# 115/115 [==============================] - 39s 340ms/step - loss: 0.0719 - accuracy: 0.9765 - val_loss: 0.8265 - val_accuracy: 0.7959
# Epoch 155/200
# 115/115 [==============================] - 38s 335ms/step - loss: 0.0581 - accuracy: 0.9770 - val_loss: 0.9181 - val_accuracy: 0.8074
# Epoch 156/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0657 - accuracy: 0.9727 - val_loss: 0.8755 - val_accuracy: 0.7997
# Epoch 157/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0550 - accuracy: 0.9820 - val_loss: 0.9458 - val_accuracy: 0.7768
# Epoch 158/200
# 115/115 [==============================] - 48s 420ms/step - loss: 0.0715 - accuracy: 0.9743 - val_loss: 0.9208 - val_accuracy: 0.8010
# Epoch 159/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0697 - accuracy: 0.9721 - val_loss: 1.0990 - val_accuracy: 0.7679
# Epoch 160/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0598 - accuracy: 0.9760 - val_loss: 1.1887 - val_accuracy: 0.7462
# Epoch 161/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0631 - accuracy: 0.9754 - val_loss: 0.7825 - val_accuracy: 0.7972
# Epoch 162/200
# 115/115 [==============================] - 47s 414ms/step - loss: 0.0436 - accuracy: 0.9891 - val_loss: 0.8463 - val_accuracy: 0.8023
# Epoch 163/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0690 - accuracy: 0.9710 - val_loss: 1.0818 - val_accuracy: 0.7857
# Epoch 164/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0666 - accuracy: 0.9743 - val_loss: 0.8089 - val_accuracy: 0.8074
# Epoch 165/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0507 - accuracy: 0.9781 - val_loss: 0.9090 - val_accuracy: 0.8048
# Epoch 166/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0456 - accuracy: 0.9831 - val_loss: 1.1392 - val_accuracy: 0.7781
# Epoch 167/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.0469 - accuracy: 0.9781 - val_loss: 0.9717 - val_accuracy: 0.7832
# Epoch 168/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0701 - accuracy: 0.9721 - val_loss: 0.8766 - val_accuracy: 0.7934
# Epoch 169/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0523 - accuracy: 0.9831 - val_loss: 1.0467 - val_accuracy: 0.7832
# Epoch 170/200
# 115/115 [==============================] - 47s 413ms/step - loss: 0.0597 - accuracy: 0.9803 - val_loss: 1.0211 - val_accuracy: 0.7934
# Epoch 171/200
# 115/115 [==============================] - 39s 338ms/step - loss: 0.0526 - accuracy: 0.9826 - val_loss: 0.8874 - val_accuracy: 0.8151
# Epoch 172/200
# 115/115 [==============================] - 38s 335ms/step - loss: 0.0527 - accuracy: 0.9765 - val_loss: 1.1152 - val_accuracy: 0.7793
# Epoch 173/200
# 115/115 [==============================] - 38s 334ms/step - loss: 0.0761 - accuracy: 0.9694 - val_loss: 1.0023 - val_accuracy: 0.7742
# Epoch 174/200
# 115/115 [==============================] - 38s 334ms/step - loss: 0.0586 - accuracy: 0.9787 - val_loss: 0.8394 - val_accuracy: 0.8214
# Epoch 175/200
# 115/115 [==============================] - 47s 413ms/step - loss: 0.0622 - accuracy: 0.9770 - val_loss: 0.8686 - val_accuracy: 0.7997
# Epoch 176/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0509 - accuracy: 0.9781 - val_loss: 0.7950 - val_accuracy: 0.8048
# Epoch 177/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0720 - accuracy: 0.9732 - val_loss: 0.9469 - val_accuracy: 0.7844
# Epoch 178/200
# 115/115 [==============================] - 38s 332ms/step - loss: 0.0579 - accuracy: 0.9781 - val_loss: 0.7743 - val_accuracy: 0.8202
# Epoch 179/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0359 - accuracy: 0.9858 - val_loss: 1.0767 - val_accuracy: 0.8023
# Epoch 180/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0648 - accuracy: 0.9732 - val_loss: 1.1001 - val_accuracy: 0.7640
# Epoch 181/200
# 115/115 [==============================] - 38s 330ms/step - loss: 0.0527 - accuracy: 0.9787 - val_loss: 0.7108 - val_accuracy: 0.8278
# Epoch 182/200
# 115/115 [==============================] - 39s 336ms/step - loss: 0.0644 - accuracy: 0.9749 - val_loss: 0.8983 - val_accuracy: 0.7997
# Epoch 183/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0672 - accuracy: 0.9738 - val_loss: 0.8790 - val_accuracy: 0.7908
# Epoch 184/200
# 115/115 [==============================] - 48s 416ms/step - loss: 0.0571 - accuracy: 0.9770 - val_loss: 0.9107 - val_accuracy: 0.7985
# Epoch 185/200
# 115/115 [==============================] - 47s 410ms/step - loss: 0.0530 - accuracy: 0.9831 - val_loss: 1.0974 - val_accuracy: 0.7819
# Epoch 186/200
# 115/115 [==============================] - 47s 412ms/step - loss: 0.0645 - accuracy: 0.9760 - val_loss: 0.8461 - val_accuracy: 0.8214
# Epoch 187/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0486 - accuracy: 0.9858 - val_loss: 0.9312 - val_accuracy: 0.7895
# Epoch 188/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0553 - accuracy: 0.9787 - val_loss: 0.7956 - val_accuracy: 0.7934
# Epoch 189/200
# 115/115 [==============================] - 47s 413ms/step - loss: 0.0460 - accuracy: 0.9831 - val_loss: 0.8547 - val_accuracy: 0.8099
# Epoch 190/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.9488 - val_accuracy: 0.8061
# Epoch 191/200
# 115/115 [==============================] - 38s 335ms/step - loss: 0.0499 - accuracy: 0.9809 - val_loss: 0.8708 - val_accuracy: 0.7985
# Epoch 192/200
# 115/115 [==============================] - 47s 409ms/step - loss: 0.0510 - accuracy: 0.9820 - val_loss: 0.9981 - val_accuracy: 0.7781
# Epoch 193/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0514 - accuracy: 0.9809 - val_loss: 1.0747 - val_accuracy: 0.7908
# Epoch 194/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0721 - accuracy: 0.9716 - val_loss: 0.9340 - val_accuracy: 0.7870
# Epoch 195/200
# 115/115 [==============================] - 38s 331ms/step - loss: 0.0467 - accuracy: 0.9836 - val_loss: 0.8879 - val_accuracy: 0.8125
# Epoch 196/200
# 115/115 [==============================] - 38s 329ms/step - loss: 0.0421 - accuracy: 0.9836 - val_loss: 0.9040 - val_accuracy: 0.8099
# Epoch 197/200
# 115/115 [==============================] - 47s 408ms/step - loss: 0.0543 - accuracy: 0.9803 - val_loss: 0.9952 - val_accuracy: 0.7934
# Epoch 198/200
# 115/115 [==============================] - 38s 328ms/step - loss: 0.0411 - accuracy: 0.9869 - val_loss: 0.8176 - val_accuracy: 0.8125
# Epoch 199/200
# 115/115 [==============================] - 47s 407ms/step - loss: 0.0459 - accuracy: 0.9863 - val_loss: 1.1427 - val_accuracy: 0.7666
# Epoch 200/200
# 115/115 [==============================] - 47s 411ms/step - loss: 0.0620 - accuracy: 0.9770 - val_loss: 1.0385 - val_accuracy: 0.8074

# %%
import matplotlib.pylab as plt
import numpy as np

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.ylabel("Accuracy (training and validation)")
plt.xlabel("Training Steps")

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.ylabel("Loss (training and validation)")
plt.xlabel("Training Steps")
plt.show()

# %%
import random
import cv2
def upload(filename):
    img = cv2.imread(os.path.join(train_dir, filename))
    img = cv2.resize(img, (224, 224) )
    img = img /255
    return img

def pre_result(image):
    x = model.predict(np.asarray([img]))[0]
    classx = np.argmax(x)
    return {Labels[classx]: x[classx]}
images = random.sample(validation_generator.filenames, 16)

for idx, filename in enumerate(images):
    img = upload(filename)
    prediction = pre_result(img)
    print("class: %s, confidence: %f" % (list(prediction.keys())[0], list(prediction.values())[0]))
    plt.imshow(img)
    plt.figure(idx)
    plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix
predictions1 = model.predict(validation_generator, steps=len(validation_generator))
y = np.argmax(predictions1, axis=1)

print("Classification Report")
cr= classification_report(y_true=validation_generator.classes,y_pred=y,target_names=validation_generator.class_indices)
print(cr)

evaluates = model.evaluate(validation_generator)
print(evaluates)
# Out:
# 50/50 [==============================] - 12s 240ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#       benign       0.75      0.92      0.83       432
#    malignant       0.87      0.63      0.73       359
#
#     accuracy                           0.79       791
#    macro avg       0.81      0.78      0.78       791
# weighted avg       0.80      0.79      0.78       791
#
# 50/50 [==============================] - 12s 231ms/step - loss: 1.0948 - accuracy: 0.7788
# [1.094834327697754, 0.778761088848114]

# %%
import pandas as pd
import numpy as np
import seaborn as sn
print('Confusion Matrix')
cm = confusion_matrix(validation_generator.classes, y)
df = pd.DataFrame(cm, columns=validation_generator.class_indices)
plt.figure(figsize=(10,7))
sn.heatmap(df, annot=True)
# Out:
# Confusion Matrix
# <Axes: >

# %%
cd /content/drive/MyDrive/train
# Out:
# /content/drive/MyDrive/train

# %%
import time
t = time.time()
export_path = "/tmp/saved_models/{}".format(int(t))
tf.keras.models.save_model(model, export_path)
export_path
# Out:
# '/tmp/saved_models/1681356483'

# %%
reloaded = tf.keras.models.load_model(export_path, custom_objects={'KerasLayer':hub.KerasLayer})

# %%
def predict_reload(image):
    probabilities = reloaded.predict(np.asarray([img]))[0]
    class_idx = np.argmax(probabilities)
    return {Labels[class_idx]: probabilities[class_idx]}

# %%
for idx, filename in enumerate(random.sample(validation_generator.filenames, 2)):
    print("SOURCE: class: %s, file: %s" % (os.path.split(filename)[0], filename))
    img = upload(filename)
    prediction = predict_reload(img)
    print("PREDICTED: class: %s, confidence: %f" % (list(prediction.keys())[0], list(prediction.values())[0]))
    plt.imshow(img)
    plt.figure(idx)
    plt.show()
# Out:
# SOURCE: class: benign, file: benign/1368.jpg
# 1/1 [==============================] - 0s 498ms/step
# PREDICTED: class: Malignant, confidence: 0.999998
# SOURCE: class: benign, file: benign/1187.jpg
# 1/1 [==============================] - 0s 24ms/step
# PREDICTED: class: Malignant, confidence: 0.999998

# %%
# convert the model to TFLite
# !mkdir "tflite_models"
TFLITE_MODEL = "tflite_models/model.tflite"

# Get the concrete function from the Keras model.
run_model = tf.function(lambda x : reloaded(x))

# Save the concrete function.
concrete_func = run_model.get_concrete_function(
    tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype)
)
# Convert the model to standard TensorFlow Lite model
converter = tf.lite.TFLiteConverter.from_concrete_functions([concrete_func])
converted_tflite_model = converter.convert()
open(TFLITE_MODEL, "wb").write(converted_tflite_model)
# Out:
# WARNING:absl:Please consider providing the trackable_obj argument in the from_concrete_functions. Providing without the trackable_obj argument is deprecated and it will use the deprecated conversion path.
# 11542820
